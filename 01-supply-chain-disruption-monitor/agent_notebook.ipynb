# %% [markdown]
# <a href="https://colab.research.google.com/github/surevmaya/Suresh-Agentic-AI-ML-Porfolio/blob/main/01-supply-chain-disruption-monitor/agent_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import anthropic

# Paste your key directly here to test
api_key = "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"

client = anthropic.Anthropic(api_key=api_key)

# Simple test
response = client.messages.create(
    model="claude-sonnet-4-6",
    max_tokens=10,
    messages=[{"role": "user", "content": "say hi"}]
)
print("✅ Key works!", response.content)
# Out:
# ✅ Key works! [TextBlock(citations=None, text='Hi there! 👋 How are you', type='text')]

# %%
# !pip install anthropic python-dotenv requests
# Out:
# Collecting anthropic
#   Downloading anthropic-0.100.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.100.0-py3-none-any.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.6/753.6 kB 13.0 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.100.0

# %%
import os
import anthropic

os.environ["ANTHROPIC_API_KEY"]="ant-api03-zoSBV_ibUMy-w-WYBAUwpIVblr-6AjfuuJKVgW2X7d2nkxRcaUjQrPo2zg6VG3ea56nwm-uhW6oE7QIt2RcBew-F7VPdQAA"
os.environ["NEWS_API_KEY"]="c9f0de46885f4e389db572e7c377496d"

client = anthropic.Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"])
print("✅ Anthropic client ready")
# Out:
# ✅ Anthropic client ready

# %%
import os
import requests
from datetime import datetime, timedelta


def search_news(query: str, days_back: int = 7) -> str:
    api_key = os.environ.get("NEWS_API_KEY")
    from_date = (datetime.now() - timedelta(days=days_back))
    from_str = from_date.strftime("%Y-%m-%d")

    url = "https://newsapi.org/v2/everything"
    params = {
        "q": query,
        "from": from_str,
        "sortBy": "relevancy",
        "language": "en",
        "pageSize": 10,
        "apiKey": api_key
    }

    try:
        response = requests.get(url, params=params)
        data = response.json()
        if data.get("status") != "ok":
            return f"News API error: {data.get('message')}"
        articles = data.get("articles", [])
        if not articles:
            return "No recent news found"
        results = []
        for article in articles[:5]:
            results.append(f"""
Title: {article['title']}
Source: {article['source']['name']}
Date: {article['publishedAt'][:10]}
Summary: {article['description']}
URL: {article['url']}
""")
        return "\n---\n".join(results)
    except Exception as e:
        return f"Error: {e}"


def search_weather_disruptions(region: str) -> str:
    api_key = os.environ.get("NEWS_API_KEY")
    query = f"{region} extreme weather flood disruption logistics"
    url = "https://newsapi.org/v2/everything"
    params = {
        "q": query,
        "from": (datetime.now() - timedelta(days=14)).strftime("%Y-%m-%d"),
        "sortBy": "relevancy",
        "language": "en",
        "pageSize": 5,
        "apiKey": api_key
    }
    try:
        response = requests.get(url, params=params)
        data = response.json()
        articles = data.get("articles", [])
        if not articles:
            return f"No weather news found for {region}"
        results = []
        for article in articles[:3]:
            results.append(f"""
Title: {article['title']}
Date: {article['publishedAt'][:10]}
Summary: {article['description']}
""")
        return "\n---\n".join(results)
    except Exception as e:
        return f"Error: {e}"


def search_port_disruptions(region: str) -> str:
    api_key = os.environ.get("NEWS_API_KEY")
    query = f"{region} port delay shipping disruption congestion"
    url = "https://newsapi.org/v2/everything"
    params = {
        "q": query,
        "from": (datetime.now() - timedelta(days=14)).strftime("%Y-%m-%d"),
        "sortBy": "relevancy",
        "language": "en",
        "pageSize": 5,
        "apiKey": api_key
    }
    try:
        response = requests.get(url, params=params)
        data = response.json()
        articles = data.get("articles", [])
        if not articles:
            return f"No port news found for {region}"
        results = []
        for article in articles[:3]:
            results.append(f"""
Title: {article['title']}
Date: {article['publishedAt'][:10]}
Summary: {article['description']}
""")
        return "\n---\n".join(results)
    except Exception as e:
        return f"Error: {e}"


def search_commodity_price(commodity: str) -> str:
    api_key = os.environ.get("NEWS_API_KEY")
    query = f"{commodity} price supply shortage spike"
    url = "https://newsapi.org/v2/everything"
    params = {
        "q": query,
        "sortBy": "publishedAt",
        "language": "en",
        "pageSize": 5,
        "apiKey": api_key
    }
    try:
        response = requests.get(url, params=params)
        data = response.json()
        articles = data.get("articles", [])
        if not articles:
            return f"No price news found for {commodity}"
        results = []
        for article in articles[:3]:
            results.append(f"""
Title: {article['title']}
Date: {article['publishedAt'][:10]}
Summary: {article['description']}
""")
        return "\n---\n".join(results)
    except Exception as e:
        return f"Error: {e}"

# %%
import anthropic

TOOLS = [
    {
        "name": "search_news",
        "description": "Search recent news for supply chain disruptions",
        "input_schema": {
            "type": "object",
            "properties": {
                "query": {
                    "type": "string",
                    "description": "Search query"
                },
                "days_back": {
                    "type": "integer",
                    "description": "How many days back to search"
                }
            },
            "required": ["query"]
        }
    },
    {
        "name": "search_weather_disruptions",
        "description": "Search for weather events affecting supply chains",
        "input_schema": {
            "type": "object",
            "properties": {
                "region": {
                    "type": "string",
                    "description": "Region to check"
                }
            },
            "required": ["region"]
        }
    },
    {
        "name": "search_port_disruptions",
        "description": "Search for port and logistics disruptions",
        "input_schema": {
            "type": "object",
            "properties": {
                "region": {
                    "type": "string",
                    "description": "Region to check"
                }
            },
            "required": ["region"]
        }
    },
    {
        "name": "search_commodity_price",
        "description": "Get commodity price context via news",
        "input_schema": {
            "type": "object",
            "properties": {
                "commodity": {
                    "type": "string",
                    "description": "Commodity name"
                }
            },
            "required": ["commodity"]
        }
    }
]


def run_tool(tool_name: str, tool_input: dict) -> str:
    if tool_name == "search_news":
        return search_news(tool_input["query"], tool_input.get("days_back", 7))
    elif tool_name == "search_weather_disruptions":
        return search_weather_disruptions(tool_input["region"])
    elif tool_name == "search_port_disruptions":
        return search_port_disruptions(tool_input["region"])
    elif tool_name == "search_commodity_price":
        return search_commodity_price(tool_input["commodity"])
    return "Tool not found"


def run_agent(commodity: str, region: str, api_key: str = None):
    client = anthropic.Anthropic(api_key=api_key)
    system_prompt = """
You are a supply chain risk intelligence agent
for a large industrial organisation.

Your job is to monitor and assess supply chain
disruption risks across commodities, suppliers,
and regions.

When analysing risks you will:
1. Search for recent news on disruptions
2. Check weather events in key regions
3. Monitor commodity price movements
4. Synthesise findings into a structured risk report

Risk scoring:
- LOW: Awareness only, no action needed
- MEDIUM: Monitor closely, prepare contingencies
- HIGH: Immediate action recommended
- CRITICAL: Escalate to leadership

Always provide:
- Evidence for each risk identified
- Confidence level in your assessment
- Recommended actions
- Sources for all findings

Be concise, factual, and actionable.
"""

    user_message = f"""
Please analyse supply chain disruption risks for:
- Commodity: {commodity}
- Region: {region}

Produce a structured risk report with:
1. Executive Summary
2. Key Risks Identified (with risk level)
3. Evidence and Sources
4. Recommended Actions
5. Monitoring Priorities
"""

    messages = [{"role": "user", "content": user_message}]

    print(f"\n🔍 Analysing supply chain risks...")
    print(f"   Commodity: {commodity}")
    print(f"   Region: {region}")
    print("=" * 50)

    while True:
        response = client.messages.create(
            model="claude-sonnet-4-6",
            max_tokens=4096,
            system=system_prompt,
            tools=TOOLS,
            messages=messages
        )

        if response.stop_reason == "end_turn":
            for block in response.content:
                if hasattr(block, "text"):
                    print(block.text)
            break

        if response.stop_reason == "tool_use":
            messages.append({
                "role": "assistant",
                "content": response.content
            })
            tool_results = []
            for block in response.content:
                if block.type == "tool_use":
                    print(f"⚙️  Calling: {block.name}({block.input})")
                    result = run_tool(block.name, block.input)
                    tool_results.append({
                        "type": "tool_result",
                        "tool_use_id": block.id,
                        "content": result
                    })
            messages.append({
                "role": "user",
                "content": tool_results
            })


# Run it!

api_key="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"
run_agent(
    commodity="LNG",
    region="Australia",
    api_key=api_key
)
# Out:
# 🔍 Analysing supply chain risks...
#    Commodity: LNG
#    Region: Australia
# ==================================================
# ⚙️  Calling: search_news({'query': 'LNG Australia supply chain disruption', 'days_back': 30})
# ⚙️  Calling: search_weather_disruptions({'region': 'Australia'})
# ⚙️  Calling: search_port_disruptions({'region': 'Australia'})
# ⚙️  Calling: search_commodity_price({'commodity': 'LNG'})
# ⚙️  Calling: search_news({'query': 'Strait of Hormuz LNG shipping disruption 2026', 'days_back': 30})
# ⚙️  Calling: search_news({'query': 'Australia LNG export terminal Chevron Woodside 2026', 'days_back': 30})
# ⚙️  Calling: search_news({'query': 'global LNG price spike energy shortage 2026', 'days_back': 30})
# I now have sufficient intelligence to compile a comprehensive, evidence-based risk report. Here it is:
#
# ---
#
# # 🛢️ SUPPLY CHAIN RISK INTELLIGENCE REPORT
# **Commodity:** Liquefied Natural Gas (LNG)
# **Region:** Australia
# **Report Date:** 7 May 2026
# **Classification:** INTERNAL — SUPPLY CHAIN RISK
#
# ---
#
# ## 1. 📋 EXECUTIVE SUMMARY
#
# Australia's LNG supply chain faces an **elevated and multi-dimensional risk environment** driven primarily by a severe geopolitical shock — the ongoing Iran war and associated Strait of Hormuz closure. While Australia itself is a **major LNG exporter** (not an importer via Hormuz), the crisis creates significant second-order risks: **global LNG price volatility**, **competitor supply disruption redirecting demand to Australian exporters**, **shipping insurance cost spikes**, and **macro energy market instability** that affects offtake agreements and infrastructure investment.
#
# No significant domestic weather events or Australian port disruptions were identified in the current period. The dominant risk vector is **external and geopolitical** in nature.
#
# **Overall Risk Level: 🟠 HIGH**
#
# ---
#
# ## 2. 🚨 KEY RISKS IDENTIFIED
#
# ### RISK 1 — Strait of Hormuz Closure & Global LNG Supply Shock
# **Risk Level: 🔴 CRITICAL**
#
# The Strait of Hormuz — through which approximately 20–25% of global LNG transits — has been disrupted by the Iran war conflict. Qatar, one of the world's largest LNG exporters, has had its LNG exports directly impacted. This is causing a structural gap in global LNG supply that redirects demand pressure onto alternative suppliers, including Australia.
#
# - **Implication for Australia:** Australian LNG terminals (e.g., Chevron's Gorgon/Wheatstone, Woodside's North West Shelf) will face surging demand from Asian and European buyers seeking alternatives to Middle Eastern supply. This creates **production and logistics strain** on Australian infrastructure.
# - **Confidence:** HIGH | **Source:** Al Jazeera (28 Apr), Semafor (5 May), Forbes (24 Apr)
#
# ---
#
# ### RISK 2 — LNG Price Spike & Contract Volatility
# **Risk Level: 🟠 HIGH**
#
# Global LNG and broader energy commodity prices are spiking sharply due to war-driven supply constraints. The "largest energy crisis in modern history" framing by credible outlets signals that price volatility is not short-term noise but a structural dislocation.
#
# - **Implication for Australia:** Spot LNG prices are likely at multi-year highs. This has dual implications: **revenue upside for exporters**, but **input cost pressure** for domestic gas consumers and industrial users reliant on gas feedstock. Any Australian entity purchasing LNG domestically faces COGS inflation.
# - **Confidence:** HIGH | **Source:** OilPrice.com (7 May), Semafor (5 May), Grist/Iran War analysis (1 May)
#
# ---
#
# ### RISK 3 — Shipping Insurance & Maritime Risk Premium
# **Risk Level: 🟠 HIGH**
#
# Even if the Strait of Hormuz partially reopens, analysts warn that shipping insurance costs could remain **up to 20× pre-war levels**. LNG tanker routing through or near conflict zones faces elevated war-risk premiums.
#
# - **Implication for Australia:** Australian LNG exports routed toward Middle Eastern or European buyers may face dramatically increased freight and insurance costs, compressing margins and potentially causing **shipping capacity constraints** as tankers avoid certain routes.
# - **Confidence:** MEDIUM-HIGH | **Source:** Al Jazeera (28 Apr), Naked Capitalism maritime analysis (24 Apr)
#
# ---
#
# ### RISK 4 — Operational Strain on Australian LNG Export Terminals
# **Risk Level: 🟠 HIGH**
#
# Chevron Q1 2026 earnings data confirms active operational context for Australian LNG assets. A surge in global demand for Australian LNG — driven by Hormuz displacement — risks pushing terminals toward **capacity ceilings**, increasing the probability of unplanned maintenance, workforce strain, and throughput bottlenecks.
#
# - **Implication for Australia:** Delivery commitments under long-term offtake agreements (particularly to Japan, South Korea, and China) may become harder to honour simultaneously with opportunistic spot market demand. Force majeure or delivery prioritisation decisions may arise.
# - **Confidence:** MEDIUM | **Source:** Chevron Q1 2026 Earnings (MarketBeat, 1 May), Baker Hughes Q1 2026 Earnings (MarketBeat, 27 Apr)
#
# ---
#
# ### RISK 5 — Helium & Industrial Gas Supply Disruption (Downstream Risk)
# **Risk Level: 🟡 MEDIUM**
#
# Qatar's LNG disruption has triggered a **severe helium shortage** affecting up to 35% of global supply. Helium is a critical co-product of LNG processing in some facilities.
#
# - **Implication for Australia:** If Australian LNG operators source or process helium as a co-product, there may be downstream industrial gas supply constraints affecting manufacturing and semiconductor-adjacent sectors. Australian helium export capacity may also face increased demand pressure.
# - **Confidence:** MEDIUM | **Source:** Yahoo Finance/Iran War Helium Shock (28 Apr)
#
# ---
#
# ### RISK 6 — Domestic Weather Events
# **Risk Level: 🟢 LOW**
#
# No significant weather disruptions were identified affecting Australian LNG infrastructure or shipping ports at this time.
#
# - **Confidence:** MEDIUM (absence of data noted; cyclone season monitoring remains prudent for NW Australia)
#
# ---
#
# ### RISK 7 — Australian Port & Logistics Disruptions
# **Risk Level: 🟢 LOW**
#
# No active port disruptions or industrial action affecting Australian LNG export terminals were detected in the current monitoring window.
#
# - **Confidence:** MEDIUM | Continued monitoring recommended.
#
# ---
#
# ## 3. 🔎 EVIDENCE AND SOURCES
#
# | # | Finding | Source | Date |
# |---|---------|--------|------|
# | 1 | Strait of Hormuz closure causing global energy crisis | Al Jazeera English | 28 Apr 2026 |
# | 2 | "Largest energy crisis in modern history" — structural LNG gap | Semafor | 5 May 2026 |
# | 3 | Hormuz shipping insurance could be 20× pre-war levels | Al Jazeera English | 28 Apr 2026 |
# | 4 | Daily Hormuz status changes creating extreme market volatility | Forbes | 24 Apr 2026 |
# | 5 | Qatar LNG disruption triggers 35% global helium shortage | Yahoo Finance | 28 Apr 2026 |
# | 6 | US acting as swing LNG supplier; global deficit confirmed | OilPrice.com | 7 May 2026 |
# | 7 | Iran war fundamentally changing global energy system | Grist | 1 May 2026 |
# | 8 | Chevron Q1 2026 earnings — LNG operational context | MarketBeat | 1 May 2026 |
# | 9 | Baker Hughes Q1 — Middle East conflict disruption noted | MarketBeat | 27 Apr 2026 |
# | 10 | Bangladesh fuel shortage — downstream demand signal | RT | 11 Apr 2026 |
# | 11 | No Australian weather disruptions detected | Internal search | 7 May 2026 |
# | 12 | No Australian port disruptions detected | Internal search | 7 May 2026 |
#
# ---
#
# ## 4. ✅ RECOMMENDED ACTIONS
#
# ### 🔴 Immediate (0–7 days)
# - **Escalate to leadership** the CRITICAL Hormuz/LNG supply shock risk and its demand-side impact on Australian LNG commitments.
# - **Contact key Australian LNG suppliers** (Chevron, Woodside) to confirm delivery schedules and capacity headroom under current surge demand.
# - **Review spot price exposure** — if your organisation purchases LNG domestically or holds short-term contracts, quantify the P&L impact of current price spikes immediately.
#
# ### 🟠 Short-Term (7–30 days)
# - **Audit offtake agreements** for force majeure clauses and delivery prioritisation triggers — prepare legal review if Hormuz disruption extends.
# - **Assess shipping insurance costs** on any LNG tanker routes relevant to your supply chain; renegotiate or hedge where possible.
# - **Model demand scenarios** — how long can operational continuity be maintained if LNG supply is constrained by 15%, 30%, or 50%?
# - **Identify alternative energy sources** (pipeline gas, renewables backup, coal fallback) as contingency for prolonged LNG tightness.
#
# ### 🟡 Medium-Term (30–90 days)
# - **Diversify supplier contracts** where possible across multiple Australian LNG terminals to reduce single-facility concentration risk.
# - **Engage with helium supply chain** if your operations are helium-dependent — secure strategic inventory given the 35% global shortage.
# - **Establish weather monitoring protocol** for NW Australia cyclone season (active Oct–Apr) affecting Pilbara/Karratha LNG infrastructure.
#
# ---
#
# ## 5. 📡 MONITORING PRIORITIES
#
# | Priority | Trigger to Watch | Frequency |
# |----------|-----------------|-----------|
# | 🔴 #1 | Strait of Hormuz status — open/closed/partial | **Daily** |
# | 🔴 #2 | LNG spot price movements (JKM/TTF benchmarks) | **Daily** |
# | 🟠 #3 | Chevron / Woodside operational announcements | **2× weekly** |
# | 🟠 #4 | Shipping insurance war-risk premium levels | **Weekly** |
# | 🟠 #5 | Iran war ceasefire / escalation signals | **Daily** |
# | 🟡 #6 | Australian NW cyclone / severe weather alerts | **Weekly** |
# | 🟡 #7 | Australian port industrial action or strikes | **Weekly** |
# | 🟡 #8 | Helium spot market pricing and availability | **Bi-weekly** |
# | 🟢 #9 | Domestic Australian energy policy changes | **Monthly** |
#
# ---
#
# ## ⚠️ REPORT CAVEATS
#
# > - No significant Australian domestic (weather/port) disruptions were detected in this cycle — **this does not mean risk is absent**, only that no signals were found in the current data window. Absence of evidence is not evidence of absence.
# > - Some sources (e.g., Naturalnews.com) should be treated with **lower editorial confidence** and cross-referenced with primary industry data.
# > - This report reflects intelligence as of **7 May 2026** and should be refreshed within **72 hours** given the rapidly evolving geopolitical situation.
#
# ---
#
# *Report generated by Supply Chain Risk Intelligence Agent | Next scheduled review: 10 May 2026*
